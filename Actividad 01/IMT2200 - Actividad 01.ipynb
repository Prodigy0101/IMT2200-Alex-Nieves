# %% [markdown]
# # <img style="float: left; padding-right: 20px; width: 200px" src="https://raw.githubusercontent.com/raxlab/imt2200-data/main/media/logo.jpg">  IMT 2200 - Introducción a Ciencia de Datos
# **Pontificia Universidad Católica de Chile**<br>
# **Instituto de Ingeniería Matemática y Computacional**<br>
# **Semestre 2025-S2**<br>
# **Profesor:** Rodrigo A. Carrasco <br>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/4/44/Plain_Yellow_Star.png/240px-Plain_Yellow_Star.png" width="50" />
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/4/44/Plain_Yellow_Star.png/240px-Plain_Yellow_Star.png" width="50" />
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/4/44/Plain_Yellow_Star.png/240px-Plain_Yellow_Star.png" width="50" />
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/4/44/Plain_Yellow_Star.png/240px-Plain_Yellow_Star.png" width="50" />
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/4/44/Plain_Yellow_Star.png/240px-Plain_Yellow_Star.png" width="50" />

# %%
# En dado caso no se visualizen todos los cambios, se recomienda utilizar Jupyter Notebook

# %% [markdown]
# # <h1><center>Actividad 01: Herramientas Computacionales para Ciencia de Datos </center></h1>
#
# ## 1. Objetivos de la Actividad
#
# Esta Actividad tiene como objetivo probar el ambiente de programación de cada estudiante, la instalación de librerías de Python. El segundo objetivo es aprender a usar GitHub, a configurar su repositorio, y entregar la actividad.

# %% [markdown]
# <img src="https://cdn-icons-png.flaticon.com/512/29/29302.png" width="150" />

# %% [markdown]
# ## 2. Módulos de Python
#
# ### 2.1 Importar módulos
#
# Se recomienda comenzar con la importación de módulos o librerías de funciones para distintos usos, o partes de una libreria
# Para facilitar la referencia a librerías en el resto del código, se acostumbra asignarles un alias. La sintaxis general a usar para importar un módulo es:
#
# ``import NOMBRE_MODULO as ALIAS_MODULO``
# o
# ``from NOMBRE_MODULO import FUNCION``

# %% [markdown]
# <img src="https://www.python.org/static/community_logos/python-logo.png" width="200" />

# %%
#Importación de librerías: importe las siguientes librerías, usando alias comunes: numpy, pandas, geopandas
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/0/0f/Grosser_Panda.JPG" width="250" />

# %% [markdown]
# <img src="https://cdn-icons-png.flaticon.com/512/123/123399.png" width="300" />

# %% [markdown]
# ## 3. Ejercicio: Inspección de Datos del Censo 2017
# El código a continuación permite descargar, leer, hacer algunos cálculos básicos y visualizar los datos de población del censo chileno de 2017 para la región metropolitana.
# En este notebook, ud. sólo debe ejecutar las celdas de código a continuación, hasta generar una figura con la distribución de población total por manzana censal en la RM. Como demostración de la ejecución exitosa del código, debe subir este notebook y la figura final a su repositorio de Github.

# %%
#Leer archivo enun DataFrame
dat = pd.read_csv('Censo2017_Manzanas.csv', delimiter=';')

dat.head().style\
    .background_gradient(cmap='YlGnBu')\
    .set_properties(**{'border': '1px solid black'})\
    .set_table_styles(
        [{'selector': 'thead th', 'props': [('background-color', '#2a9d8f'),
                                            ('color', 'white'),
                                            ('font-weight', 'bold')]}]
    )
# Out:
# <style type="text/css">
# #T_3b3df thead th {
#   background-color: #2a9d8f;
#   color: white;
#   font-weight: bold;
# }
# #T_3b3df_row0_col0, #T_3b3df_row0_col1, #T_3b3df_row0_col2, #T_3b3df_row0_col3, #T_3b3df_row0_col4, #T_3b3df_row0_col5, #T_3b3df_row0_col6, #T_3b3df_row0_col7, #T_3b3df_row0_col8, #T_3b3df_row0_col9, #T_3b3df_row0_col18, #T_3b3df_row0_col20, #T_3b3df_row0_col21, #T_3b3df_row0_col22, #T_3b3df_row0_col23, #T_3b3df_row0_col24, #T_3b3df_row0_col25, #T_3b3df_row0_col26, #T_3b3df_row0_col27, #T_3b3df_row0_col28, #T_3b3df_row0_col30, #T_3b3df_row0_col31, #T_3b3df_row0_col32, #T_3b3df_row0_col33, #T_3b3df_row0_col34, #T_3b3df_row0_col35, #T_3b3df_row0_col36, #T_3b3df_row0_col37, #T_3b3df_row0_col38, #T_3b3df_row0_col39, #T_3b3df_row0_col40, #T_3b3df_row0_col41, #T_3b3df_row0_col42, #T_3b3df_row0_col43, #T_3b3df_row0_col44, #T_3b3df_row0_col45, #T_3b3df_row0_col46, #T_3b3df_row0_col47, #T_3b3df_row0_col48, #T_3b3df_row0_col49, #T_3b3df_row0_col50, #T_3b3df_row0_col51, #T_3b3df_row0_col52, #T_3b3df_row0_col53, #T_3b3df_row0_col54, #T_3b3df_row0_col55, #T_3b3df_row0_col56, #T_3b3df_row0_col57, #T_3b3df_row0_col58, #T_3b3df_row1_col0, #T_3b3df_row1_col1, #T_3b3df_row1_col2, #T_3b3df_row1_col3, #T_3b3df_row1_col4, #T_3b3df_row1_col5, #T_3b3df_row1_col7, #T_3b3df_row1_col24, #T_3b3df_row1_col25, #T_3b3df_row1_col27, #T_3b3df_row1_col28, #T_3b3df_row1_col29, #T_3b3df_row1_col30, #T_3b3df_row1_col34, #T_3b3df_row1_col35, #T_3b3df_row1_col37, #T_3b3df_row1_col39, #T_3b3df_row1_col40, #T_3b3df_row1_col41, #T_3b3df_row1_col42, #T_3b3df_row1_col44, #T_3b3df_row1_col45, #T_3b3df_row1_col46, #T_3b3df_row1_col47, #T_3b3df_row1_col50, #T_3b3df_row1_col52, #T_3b3df_row1_col53, #T_3b3df_row1_col54, #T_3b3df_row1_col55, #T_3b3df_row1_col56, #T_3b3df_row1_col57, #T_3b3df_row2_col0, #T_3b3df_row2_col1, #T_3b3df_row2_col2, #T_3b3df_row2_col3, #T_3b3df_row2_col4, #T_3b3df_row2_col5, #T_3b3df_row2_col7, #T_3b3df_row2_col24, #T_3b3df_row2_col25, #T_3b3df_row2_col27, #T_3b3df_row2_col28, #T_3b3df_row2_col29, #T_3b3df_row2_col30, #T_3b3df_row2_col31, #T_3b3df_row2_col33, #T_3b3df_row2_col34, #T_3b3df_row2_col35, #T_3b3df_row2_col36, #T_3b3df_row2_col37, #T_3b3df_row2_col39, #T_3b3df_row2_col40, #T_3b3df_row2_col41, #T_3b3df_row2_col42, #T_3b3df_row2_col44, #T_3b3df_row2_col45, #T_3b3df_row2_col47, #T_3b3df_row2_col50, #T_3b3df_row2_col52, #T_3b3df_row2_col53, #T_3b3df_row2_col54, #T_3b3df_row2_col55, #T_3b3df_row2_col56, #T_3b3df_row2_col57, #T_3b3df_row3_col0, #T_3b3df_row3_col1, #T_3b3df_row3_col2, #T_3b3df_row3_col3, #T_3b3df_row3_col4, #T_3b3df_row3_col5, #T_3b3df_row3_col7, #T_3b3df_row3_col19, #T_3b3df_row3_col24, #T_3b3df_row3_col25, #T_3b3df_row3_col26, #T_3b3df_row3_col27, #T_3b3df_row3_col28, #T_3b3df_row3_col29, #T_3b3df_row3_col34, #T_3b3df_row3_col35, #T_3b3df_row3_col39, #T_3b3df_row3_col40, #T_3b3df_row3_col47, #T_3b3df_row3_col52, #T_3b3df_row3_col53, #T_3b3df_row3_col54, #T_3b3df_row3_col55, #T_3b3df_row3_col56, #T_3b3df_row3_col57, #T_3b3df_row4_col0, #T_3b3df_row4_col1, #T_3b3df_row4_col2, #T_3b3df_row4_col3, #T_3b3df_row4_col4, #T_3b3df_row4_col5, #T_3b3df_row4_col7, #T_3b3df_row4_col25, #T_3b3df_row4_col26, #T_3b3df_row4_col28, #T_3b3df_row4_col29, #T_3b3df_row4_col30, #T_3b3df_row4_col33, #T_3b3df_row4_col34, #T_3b3df_row4_col35, #T_3b3df_row4_col37, #T_3b3df_row4_col39, #T_3b3df_row4_col40, #T_3b3df_row4_col41, #T_3b3df_row4_col42, #T_3b3df_row4_col44, #T_3b3df_row4_col45, #T_3b3df_row4_col46, #T_3b3df_row4_col47, #T_3b3df_row4_col49, #T_3b3df_row4_col50, #T_3b3df_row4_col52, #T_3b3df_row4_col53, #T_3b3df_row4_col54, #T_3b3df_row4_col55, #T_3b3df_row4_col56, #T_3b3df_row4_col57 {
#   background-color: #ffffd9;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_3b3df_row0_col10, #T_3b3df_row0_col11, #T_3b3df_row0_col12, #T_3b3df_row0_col13, #T_3b3df_row0_col14, #T_3b3df_row0_col15, #T_3b3df_row0_col16, #T_3b3df_row0_col17, #T_3b3df_row1_col10, #T_3b3df_row1_col11, #T_3b3df_row1_col12, #T_3b3df_row1_col13, #T_3b3df_row1_col14, #T_3b3df_row1_col15, #T_3b3df_row1_col16, #T_3b3df_row1_col17, #T_3b3df_row2_col10, #T_3b3df_row2_col11, #T_3b3df_row2_col12, #T_3b3df_row2_col13, #T_3b3df_row2_col14, #T_3b3df_row2_col15, #T_3b3df_row2_col16, #T_3b3df_row2_col17, #T_3b3df_row3_col10, #T_3b3df_row3_col11, #T_3b3df_row3_col12, #T_3b3df_row3_col13, #T_3b3df_row3_col14, #T_3b3df_row3_col15, #T_3b3df_row3_col16, #T_3b3df_row3_col17, #T_3b3df_row4_col10, #T_3b3df_row4_col11, #T_3b3df_row4_col12, #T_3b3df_row4_col13, #T_3b3df_row4_col14, #T_3b3df_row4_col15, #T_3b3df_row4_col16, #T_3b3df_row4_col17 {
#   border: 1px solid black;
# }
# #T_3b3df_row0_col19, #T_3b3df_row0_col29, #T_3b3df_row1_col9, #T_3b3df_row1_col36, #T_3b3df_row1_col48, #T_3b3df_row2_col26, #T_3b3df_row2_col32, #T_3b3df_row2_col38, #T_3b3df_row2_col46, #T_3b3df_row3_col18, #T_3b3df_row3_col20, #T_3b3df_row3_col21, #T_3b3df_row3_col22, #T_3b3df_row3_col23, #T_3b3df_row3_col30, #T_3b3df_row3_col31, #T_3b3df_row3_col33, #T_3b3df_row3_col37, #T_3b3df_row3_col41, #T_3b3df_row3_col42, #T_3b3df_row3_col43, #T_3b3df_row3_col44, #T_3b3df_row3_col45, #T_3b3df_row3_col49, #T_3b3df_row3_col50, #T_3b3df_row3_col51, #T_3b3df_row4_col6, #T_3b3df_row4_col8, #T_3b3df_row4_col19, #T_3b3df_row4_col24, #T_3b3df_row4_col27, #T_3b3df_row4_col31, #T_3b3df_row4_col58 {
#   background-color: #081d58;
#   color: #f1f1f1;
#   border: 1px solid black;
# }
# #T_3b3df_row1_col6, #T_3b3df_row1_col8, #T_3b3df_row1_col58, #T_3b3df_row4_col36 {
#   background-color: #225da8;
#   color: #f1f1f1;
#   border: 1px solid black;
# }
# #T_3b3df_row1_col18 {
#   background-color: #2073b2;
#   color: #f1f1f1;
#   border: 1px solid black;
# }
# #T_3b3df_row1_col19, #T_3b3df_row2_col19, #T_3b3df_row4_col43 {
#   background-color: #40b5c4;
#   color: #f1f1f1;
#   border: 1px solid black;
# }
# #T_3b3df_row1_col20, #T_3b3df_row1_col51, #T_3b3df_row2_col20, #T_3b3df_row2_col51, #T_3b3df_row3_col36 {
#   background-color: #1d90c0;
#   color: #f1f1f1;
#   border: 1px solid black;
# }
# #T_3b3df_row1_col21, #T_3b3df_row2_col48 {
#   background-color: #216daf;
#   color: #f1f1f1;
#   border: 1px solid black;
# }
# #T_3b3df_row1_col22 {
#   background-color: #253997;
#   color: #f1f1f1;
#   border: 1px solid black;
# }
# #T_3b3df_row1_col23 {
#   background-color: #1f80b8;
#   color: #f1f1f1;
#   border: 1px solid black;
# }
# #T_3b3df_row1_col26 {
#   background-color: #f4fbc1;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_3b3df_row1_col31 {
#   background-color: #c6e9b4;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_3b3df_row1_col32, #T_3b3df_row3_col38 {
#   background-color: #253795;
#   color: #f1f1f1;
#   border: 1px solid black;
# }
# #T_3b3df_row1_col33 {
#   background-color: #e8f6b1;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_3b3df_row1_col38 {
#   background-color: #52bcc2;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_3b3df_row1_col43, #T_3b3df_row2_col6, #T_3b3df_row2_col8, #T_3b3df_row2_col58 {
#   background-color: #24419a;
#   color: #f1f1f1;
#   border: 1px solid black;
# }
# #T_3b3df_row1_col49 {
#   background-color: #eff9b6;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_3b3df_row2_col9 {
#   background-color: #7cccbb;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_3b3df_row2_col18 {
#   background-color: #2296c1;
#   color: #f1f1f1;
#   border: 1px solid black;
# }
# #T_3b3df_row2_col21 {
#   background-color: #1f93c0;
#   color: #f1f1f1;
#   border: 1px solid black;
# }
# #T_3b3df_row2_col22 {
#   background-color: #36abc3;
#   color: #f1f1f1;
#   border: 1px solid black;
# }
# #T_3b3df_row2_col23 {
#   background-color: #f3fabf;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_3b3df_row2_col43, #T_3b3df_row2_col49 {
#   background-color: #31a5c2;
#   color: #f1f1f1;
#   border: 1px solid black;
# }
# #T_3b3df_row3_col6, #T_3b3df_row3_col8, #T_3b3df_row3_col58 {
#   background-color: #1b2c80;
#   color: #f1f1f1;
#   border: 1px solid black;
# }
# #T_3b3df_row3_col9 {
#   background-color: #1d2e83;
#   color: #f1f1f1;
#   border: 1px solid black;
# }
# #T_3b3df_row3_col32 {
#   background-color: #2165ab;
#   color: #f1f1f1;
#   border: 1px solid black;
# }
# #T_3b3df_row3_col46, #T_3b3df_row4_col3

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180499 entries, 0 to 180498
# Data columns (total 59 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   REGION          180499 non-null  int64
#  1   PROVINCIA       180499 non-null  int64
#  2   COMUNA          180499 non-null  int64
#  3   DC              180499 non-null  int64
#  4   AREA            180499 non-null  int64
#  5   ZC_LOC          180499 non-null  int64
#  6   MZ_ENT          180499 non-null  int64
#  7   ID_ZONA_LOC     180499 non-null  int64
#  8   ID_MANZENT      180499 non-null  int64
#  9   PERSONAS        180499 non-null  int64
#  10  HOMBRES         180499 non-null  object
#  11  MUJERES         180499 non-null  object
#  12  EDAD_0A5        180499 non-null  object
#  13  EDAD_6A14       180499 non-null  object
#  14  EDAD_15A64      180499 non-null  object
#  15  EDAD_65YMAS     180499 non-null  object
#  16  INMIGRANTES     180499 non-null  object
#  17  PUEBLO          180499 non-null  object
#  18  VIV_PART        180499 non-null  int64
#  19  VIV_COL         180499 non-null  int64
#  20  VPOMP           180499 non-null  int64
#  21  TOTAL_VIV       180499 non-null  int64
#  22  CANT_HOG        180499 non-null  int64
#  23  P01_1           180499 non-null  int64
#  24  P01_2           180499 non-null  int64
#  25  P01_3           180499 non-null  int64
#  26  P01_4           180499 non-null  int64
#  27  P01_5           180499 non-null  int64
#  28  P01_6           180499 non-null  int64
#  29  P01_7           180499 non-null  int64
#  30  P03A_1          180499 non-null  int64
#  31  P03A_2          180499 non-null  int64
#  32  P03A_3          180499 non-null  int64
#  33  P03A_4          180499 non-null  int64
#  34  P03A_5          180499 non-null  int64
#  35  P03A_6          180499 non-null  int64
#  36  P03B_1          180499 non-null  int64
#  37  P03B_2          180499 non-null  int64
#  38  P03B_3          180499 non-null  int64
#  39  P03B_4          180499 non-null  int64
#  40  P03B_5          180499 non-null  int64
#  41  P03B_6          180499 non-null  int64
#  42  P03B_7          180499 non-null  int64
#  43  P03C_1          180499 non-null  int64
#  44  P03C_2          180499 non-null  int64
#  45  P03C_3          180499 non-null  int64
#  46  P03C_4          180499 non-null  int64
#  47  P03C_5          180499 non-null  int64
#  48  MATACEP         180499 non-null  int64
#  49  MATREC          180499 non-null  int64
#  50  MATIRREC        180499 non-null  int64
#  51  P05_1           180499 non-null  int64
#  52  P05_2           180499 non-null  int64
#  53  P05_3           180499 non-null  int64
#  54  P05_4           180499 non-null  int64
#  55  REGION_15R      180499 non-null  int64
#  56  PROVINCIA_15R   180499 non-null  int64
#  57  COMUNA_15R      180499 non-null  int64
#  58  ID_MANZENT_15R  180499 non-null  int64
# dtypes: int64(51), object(8)
# memory usage: 81.2+ MB

# %%
📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊

# %%
📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊📊

# %% [markdown]
# ### Pregunta: ¿Cuál era la población total de Chile en 2017?
#
# Para responderla podemos hacer un cálculo sencillo y sumar todos los datos de la columna `PERSONAS`:

# %%
#Total de población
total_pop=dat['PERSONAS'].sum()
print(f'Población total en 2017: {total_pop}')
# Out:
# Población total en 2017: 17574003

# %% [markdown]
# También podemos usar algunas funciones más avanzadas de `pandas`para analizar la distribución de personas por región y edad:

# %%
#Distribución por edad y género
cols=['EDAD_0A5','EDAD_6A14','EDAD_15A64','EDAD_65YMAS']
for col in cols:
    dat[col]=dat[col].replace('*',0).astype(float)
    
pv = pd.pivot_table(
    dat,
    index='REGION',
    values=cols,
    aggfunc='sum',
    margins=False
)

pv.style\
  .background_gradient(cmap='Reds')\
  .set_properties(**{'border': '1px solid black'})\
  .set_table_styles(
      [{'selector': 'thead th',
        'props': [('background-color', '#8B0000'),
                  ('color', 'white'),
                  ('font-weight', 'bold')]}]
  )
# Out:
# <style type="text/css">
# #T_8be87 thead th {
#   background-color: #8B0000;
#   color: white;
#   font-weight: bold;
# }
# #T_8be87_row0_col0, #T_8be87_row1_col2 {
#   background-color: #ffeee6;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row0_col1, #T_8be87_row13_col0 {
#   background-color: #fff0e8;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row0_col2, #T_8be87_row2_col2, #T_8be87_row14_col0, #T_8be87_row14_col2 {
#   background-color: #fff2eb;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row0_col3, #T_8be87_row15_col0 {
#   background-color: #ffeee7;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row1_col0, #T_8be87_row1_col1 {
#   background-color: #fee9df;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row1_col3 {
#   background-color: #fee8dd;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row2_col0, #T_8be87_row2_col1 {
#   background-color: #fff1ea;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row2_col3 {
#   background-color: #fff0e9;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row3_col0, #T_8be87_row3_col1 {
#   background-color: #fee7db;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row3_col2, #T_8be87_row3_col3 {
#   background-color: #fee5d9;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row4_col0 {
#   background-color: #fdc6b0;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row4_col1 {
#   background-color: #fcc1a8;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row4_col2 {
#   background-color: #fcab8f;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row4_col3 {
#   background-color: #fcc4ad;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row5_col0 {
#   background-color: #fee3d7;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row5_col1 {
#   background-color: #fee3d6;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row5_col2 {
#   background-color: #fee1d3;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row5_col3 {
#   background-color: #fee1d4;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row6_col0, #T_8be87_row8_col1, #T_8be87_row8_col3 {
#   background-color: #fee2d5;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row6_col1 {
#   background-color: #fee0d2;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row6_col2 {
#   background-color: #fedbcc;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row6_col3 {
#   background-color: #fedfd0;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row7_col0 {
#   background-color: #fdcdb9;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row7_col1 {
#   background-color: #fdcab5;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row7_col2 {
#   background-color: #fdc5ae;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row7_col3 {
#   background-color: #fdc9b3;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row8_col0, #T_8be87_row9_col3 {
#   background-color: #fee4d8;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row8_col2 {
#   background-color: #fedecf;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row9_col0 {
#   background-color: #fee7dc;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row9_col1, #T_8be87_row9_col2 {
#   background-color: #fee5d8;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row10_col0, #T_8be87_row10_col1, #T_8be87_row10_col2, #T_8be87_row10_col3 {
#   background-color: #fff5f0;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row11_col0, #T_8be87_row11_col3 {
#   background-color: #fff4ef;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row11_col1 {
#   background-color: #fff4ee;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row11_col2 {
#   background-color: #fff3ed;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row12_col0, #T_8be87_row12_col1, #T_8be87_row12_col2, #T_8be87_row12_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   border: 1px solid black;
# }
# #T_8be87_row13_col1, #T_8be87_row13_col3 {
#   background-color: #ffefe8;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row13_col2, #T_8be87_row15_col3 {
#   background-color: #ffede5;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row14_col1, #T_8be87_row14_col3 {
#   background-color: #fff2ec;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row15_col1 {
#   background-color: #ffece4;
#   color: #000000;
#   border: 1px solid black;
# }
# #T_8be87_row15_col2 {
#   background-color: #feeae0;
#   color: #000000;
#   border: 1px solid black;
# }
# </style>
# <table id="T_8be87">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8be87_level0_col0" class="col_heading level0 col0" >EDAD_0A5</th>
#       <th id="T_8be87_level0_col1" class="col_heading level0 col1" >EDAD_15A64</th>
#       <th id="T_8be87_level0_col2" class="col_heading level0 col2" >EDAD_65YMAS</th>
#       <th id="T_8be87_level0_col3" class="col_heading level0 col3" >EDAD_6A14</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >REGION</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8be87_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_8be87_row0_col0" class="data row0 col0" >27089.000000</td>
#       <td id="T_8be87_row0_col1" class="data row0 col1" >225991.000000</td>
#       <td id="T_8be87_row0_col2" class="data row0 col2" >22784.000000</td>
#       <td id="T_8be87_row0_col3" class="data row0 col3" >42860.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8be87_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_8be87_row1_col0" class="data row1 col0" >40763.000000</td>
#       <td id="T_8be87_row1_col1" class="data row1 col1" >427746.000000</td>
#       <td id="T_8be87_row1_col2" class="data row1 col2" >40299.000000</td>
#       <td id="T_8be87_row1_col3" class="data row1 col3" >70497.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8be87_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_8be87_row2_col0" class="data row2 col0" >18862.000000</td>
#       <td id="T_8be87_row2_col1" class="data row2 col1" >188979.000000</td>
#       <td id="T_8be87_row2_col2" class="data row2 col2" >23711.000000</td>
#       <td id="T_8be87_row2_col3" class="data row2 col3" >33304.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8be87_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_8be87_row3_col0" class="data row3 col0" >49130.000000</td>
#       <td id="T_8be87_row3_col1" class="data row3 col1" >498186.000000</td>
#       <td id="T_8be87_row3_col2" class="data row3 col2" >77212.000000</td>
#       <td id="T_8be87_row3_col3" class="data row3 col3" >83390.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8be87_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_8be87_row4_col0" class="data row4 col0" >110371.000000</td>
#       <td id="T_8be87_row4_col1" class="data row4 col1" >1212273.000000</td>
#       <td id="T_8be87_row4_col2" class="data row4 col2" >222900.000000</td>
#       <td id="T_8be87_row4_col3" class="data row4 col3" >176235.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8be87_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_8be87_row5_col0" class="data row5 col0" >58426.000000</td>
#       <td id="T_8be87_row5_col1" class="data row5 col1" >609723.000000</td>
#       <td id="T_8be87_row5_col2" class="data row5 col2" >96677.000000</td>
#       <td id="T_8be87_row5_col3" class="data row5 col3" >100364.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8be87_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_8be87_row6_col0" class="data row6 col0" >62106.000000</td>
#       <td id="T_8be87_row6_col1" class="data row6 col1" >695161.000000</td>
#       <td id="T_8be87_row6_col2" class="data row6 col2" >111206.000000</td>
#       <td id="T_8be87_row6_col3" class="data row6 col3" >108436.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8be87_level0_

# %% [markdown]
# Y podemos graficar la cantidad por región:

# %%
fig = plt.figure(figsize=(11,11))
ax = fig.add_subplot(111)

pv.plot(kind='bar', ax=ax, color=['#FFA726', '#29B6F6', '#AB47BC', '#EF5350'])

ax.set_ylabel('Número de personas', fontsize=14, fontweight='bold', color='#333333')
ax.set_xlabel('Región', fontsize=14, fontweight='bold', color='#333333')
ax.set_title('Distribución de población por Edad y Región\nChile, Censo 2017', fontsize=20, fontweight='bold', y=1.05, color='#222222')

ax.grid(axis='y', linestyle='--', alpha=0.7)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Creación de un Mapa con información del Censo
#
# A continuación usaremos librerías de geopandas para conectar un mapa de la Región Metropolitana con datos del Censo de 2017.

# %%
#Leer datos censales
manz=gpd.read_file('R13/MANZANA_IND_C17.shp')
com=gpd.read_file('R13/COMUNA_C17.shp')

# %% [markdown]
# Geopandas permite graficar archivos de mapas de múltiples formas. Para más información pueden revisar el siguiente enlace: https://geopandas.org/en/stable/docs/user_guide/mapping.html

# %% [markdown]
# fig, ax = plt.subplots(figsize=(10,8))
#
# com.plot(ax=ax, color='#4FA3D1', edgecolor='gray', linewidth=0.6)
#
# ax.axis('off')
# ax.set_title("Región Metropolitana", fontsize=14, fontweight='bold')
#
# plt.show()

# %%
🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼🔼

# %% [markdown]
# 💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫💫

# %% [markdown]
# El siguiente código conecta el mapa de la Región Metropolitana con la población por manzana del Censo 2017. Edite el código para que la figura tenga su nombre en el Titulo

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.colors as colors

fig, ax = plt.subplots(figsize=(10,13))
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)

manz.plot(
    ax=ax,
    column='TOTAL_PERS',
    cmap='cividis',  # paleta suave y moderna
    legend=True,
    vmin=0,
    vmax=1000,
    cax=cax,
    edgecolor='lightgray',
    linewidth=0.3,
    alpha=0.8
)

com_projected.boundary.plot(ax=ax, lw=0.4, color='gray', alpha=0.6)

xlim = [-70.9, -70.4]
ylim = [-33.7, -33.2]
ax.set_xlim(xlim)
ax.set_ylim(ylim)

for x, y, label in zip(com_projected.geometry.centroid.x, com_projected.geometry.centroid.y, com_projected.NOM_COMUNA):
    if xlim[0] < x < xlim[1] and ylim[0] < y < ylim[1]:
        ax.text(x, y, label, fontsize=9, color='black')

ax.axis('off')
ax.set_title("Población por Manzana y Comuna (Censo 2017)", fontsize=14)

plt.show()


## Reemplace 'XXX' por su apellido
ax.set_title('RM - Población total por manzana - Censo 2017 - Ejecutado por Alex Nieves',fontsize=10)

## Reemplace 'XXX' por su apellido en el nombre del archivo de salida 
fig.savefig('PoblacionRM_C2017_Aex Nieves.jpg')

# %% [markdown]
# ## 5. Cierre de la Actividad 01: Repositorio presonal
#
# Para terminar la Actividad 01, deben hacer los siguientes pasos:
# - Crear un repositorio en su cuenta personal con el nombre ``IMT2200-<NOMBRE>-<APELLIDO>`` y clonar en su computador.
# - Crear una carpeta adentro llamada "Actividad 01" y copiar adentro el contenido de la carpeta "Actividad 01" del repositorio del curso.
# - Actualizar el repositorio agregando el Notebook de Jupyter y la imagen con el Mapa con su nombre.
# - Editar el archivo ``README.md`` para describir su repositorio.
# - Entregar en el módulo ``Actividad 1`` en Canvas la URL de su repositorio para corrección.
